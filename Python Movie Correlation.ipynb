# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import re

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# Read data
movieData = pd.read_csv(r'/home/admin/Projects/Data Analytics/Correlation in Python/movies.csv')

# %%
# Looking at Data
movieData.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Checking for missing data

# Calculate percentage of missing values
for col in movieData.columns:
    percentage_missing = np.mean(movieData[col].isnull())
    print('{} - {}%'.format(col, round(percentage_missing * 100, 2)))
# Out:
# name - 0.0%
# rating - 1.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.04%
# votes - 0.04%
# director - 0.0%
# writer - 0.04%
# star - 0.01%
# country - 0.04%
# budget - 0.0%
# gross - 0.0%
# company - 0.22%
# runtime - 0.05%
# yearcorrect - 0.03%

# %%
# Checking Data type of columns
movieData.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Change data of 'gross' and 'budget'

# Fill NaNs with 0
movieData['budget'] = movieData['budget'].fillna(0)
movieData['gross'] = movieData['gross'].fillna(0)

# Convert columns from float64 to int64
movieData['budget'] = movieData['budget'].astype('int64')
movieData['gross'] = movieData['gross'].astype('int64')

# Verify the changes
print("\nData types after conversion:")
print(movieData.dtypes)
# Out:
# Data types after conversion:
# name            object
# rating          object
# genre           object
# year             int64
# released        object
# score          float64
# votes          float64
# director        object
# writer          object
# star            object
# country         object
# budget           int64
# gross            int64
# company         object
# runtime        float64
# yearcorrect     object
# dtype: object

# %%
# Create better Year Column

# Fill NaN values with empty string
movieData['released'] = movieData['released'].fillna('')

# Extract year from 'released' column using regular expression
movieData['yearcorrect'] = movieData['released'].apply(lambda x: re.search(r'\d{4}', str(x)).group() if re.search(r'\d{4}', str(x)) else None)

movieData
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
movieData.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
# Scatter plot with budget vs gross

plt.scatter(x=movieData['budget'], y=movieData['gross'])

plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget for Film')
plt.ylabel('Gross Earnings')

plt.show()

# %%
# Plot budget vs gross using seaborn
plt.title('Budget vs Gross Earnings')

sns.regplot(x="budget", y="gross", data=movieData, scatter_kws={"color": "red"}, line_kws={"color": "blue"})

plt.xlabel('Budget for Film')
plt.ylabel('Gross Earnings')
# Out:
# Text(0, 0.5, 'Gross Earnings')

# %%
# Looking at correlation

# Selects numeric columns 
numeric_cols = movieData.select_dtypes(include=[np.number])

# Compute correlation matrix
correlation_matrix = numeric_cols.corr()

print(correlation_matrix)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
# Selects numeric columns 
numeric_cols = movieData.select_dtypes(include=[np.number])

# Compute correlation matrix
correlation_matrix = numeric_cols.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
movieData_numerized = movieData

# Convert object columns to categorical and then to numerical codes
for col_name in movieData_numerized.columns:
    if(movieData_numerized[col_name].dtype == 'object'):
        movieData_numerized[col_name] = movieData_numerized[col_name].astype('category')
        movieData_numerized[col_name] = movieData_numerized[col_name].cat.codes

movieData_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1706    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1493    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1772    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1493    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1544    7.3   108000.0      1054     521
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 7663  3705      -1      6  2020      2965    3.1       18.0      1500    2289
# 7664  1678      -1      4  2020      1108    4.7       36.0       774    2614
# 7665  4717      -1      6  2020       194    5.7       29.0      2061    2683
# 7666  2843      -1      6  2020      2818    NaN        NaN      1184    1824
# 7667  5394      -1     10  2020       392    5.7        7.0      2165    3344
#
# ...

# %%
# Compute correlation matrix
correlation_matrix = movieData_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
correlation_mat = movieData_numerized.corr()

corr_pairs = correlation_mat.unstack()

sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# budget       genre         -0.334021
# genre        budget        -0.334021
#              gross         -0.234297
# gross        genre         -0.234297
# votes        genre         -0.145307
#                               ...
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# gross        votes          0.632834
# votes        gross          0.632834
# gross        budget         0.750157
# budget       gross          0.750157
# yearcorrect  year           0.996397
# year         yearcorrect    0.996397
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64
